# %%
import pandas as pd

# %%
wd = {
    'day': ['sunday', 'monay', 'tuesday', 'wednesday', 'thursday', 'friday', 'saturday'],
    'temp': [32,3,2, 4, 3, 5, 7],
    'wind': [5,4,3, 1, 4, 6, 7],
    'event': ['rain', 'sunny', 'snow', 'rain', 'sunny', 'snow', 'sunny']
}

df = pd.DataFrame(wd)

df
# Out:
#          day  temp  wind  event
# 0     sunday    32     5   rain
# 1      monay     3     4  sunny
# 2    tuesday     2     3   snow
# 3  wednesday     4     1   rain
# 4   thursday     3     4  sunny
# 5     friday     5     6   snow
# 6   saturday     7     7  sunny

# %%
df.nunique()
# Out:
# day      6
# temp     6
# wind     6
# event    3
# dtype: int64

# %%
df.describe()
# Out:
#             temp      wind
# count   7.000000  7.000000
# mean    8.000000  4.285714
# std    10.708252  1.976047
# min     2.000000  1.000000
# 25%     3.000000  3.500000
# 50%     4.000000  4.000000
# 75%     6.000000  5.500000
# max    32.000000  7.000000

# %%
df['temp'].sum()
# Out:
# 37

# %%
df['wind'].count()
# Out:
# 3

# %%
df.shape
# Out:
# (3, 4)

# %%
df[2:4]
#it includes 2 but not 4
# Out:
#                 day  temp  wind event
# 2  tuesdaywednesday     2     3  snow
# 3          thursday     4     1  rain

# %%
df.columns
# Out:
# Index(['day', 'temp', 'wind', 'event'], dtype='object')

# %%
df.day
# Out:
# 0       sunday
# 1        monay
# 2      tuesday
# 3    wednesday
# 4     thursday
# 5       friday
# 6     saturday
# Name: day, dtype: object

# %%
df['event']
# Out:
# 0     rain
# 1    sunny
# 2     snow
# 3     rain
# 4    sunny
# 5     snow
# 6    sunny
# Name: event, dtype: object

# %%
#to print few columns from the data set use this
df[['day', 'event']]
# Out:
#          day  event
# 0     sunday   rain
# 1      monay  sunny
# 2    tuesday   snow
# 3  wednesday   rain
# 4   thursday  sunny
# 5     friday   snow
# 6   saturday  sunny

# %% [markdown]
# operation on dataset

# %%
df['temp'].sum()
# Out:
# 56

# %%
df[df.temp>=32]
# Out:
#       day  temp  wind event
# 0  sunday    32     5  rain

# %%
df[df.temp == df.temp.max()]
# Out:
#       day  temp  wind event
# 0  sunday    32     5  rain

# %%
df['temp'].mean()
# Out:
# 8.0

# %%
df['temp'].max()
# Out:
# 32

# %%
df['temp'].min()
# Out:
# 2

# %%
df.describe()
# Out:
#             temp      wind
# count   7.000000  7.000000
# mean    8.000000  4.285714
# std    10.708252  1.976047
# min     2.000000  1.000000
# 25%     3.000000  3.500000
# 50%     4.000000  4.000000
# 75%     6.000000  5.500000
# max    32.000000  7.000000

# %%
 df[['day', 'temp']][df.temp == df.temp.max()]
# Out:
#       day  temp
# 0  sunday    32

# %%
df.head()
# Out:
#          day  temp  wind  event
# 0     sunday    32     5   rain
# 1      monay     3     4  sunny
# 2    tuesday     2     3   snow
# 3  wednesday     4     1   rain
# 4   thursday     3     4  sunny

# %%
df[['day', 'wind', 'temp']][df.temp == df.temp.min()]
# Out:
#        day  wind  temp
# 2  tuesday     3     2

# %%
df[['day', 'wind', 'temp']][df.wind == df.wind.max()]
# Out:
#         day  wind  temp
# 6  saturday     7     7

# %%
df.head()
# Out:
#            temp  wind  event
# day
# sunday       32     5   rain
# monay         3     4  sunny
# tuesday       2     3   snow
# wednesday     4     1   rain
# thursday      3     4  sunny

# %%
# df.set_index('day', inplace = True)
df.reset_index(inplace = True)

# %%
df
# Out:
#          day  temp  wind  event
# 0     sunday    32     5   rain
# 1      monay     3     4  sunny
# 2    tuesday     2     3   snow
# 3  wednesday     4     1   rain
# 4   thursday     3     4  sunny
# 5     friday     5     6   snow
# 6   saturday     7     7  sunny

# %%
df.set_index('day', inplace = True)

# %%
df.head()
# Out:
#            temp  wind  event
# day
# sunday       32     5   rain
# monay         3     4  sunny
# tuesday       2     3   snow
# wednesday     4     1   rain
# thursday      3     4  sunny

# %%
df.loc['sunday']
# Out:
# temp       32
# wind        5
# event    rain
# Name: sunday, dtype: object

# %%
df.reset_index(inplace = True)
df
# Out:
#    index        day  temp  wind  event
# 0      0     sunday    32     5   rain
# 1      1      monay     3     4  sunny
# 2      2    tuesday     2     3   snow
# 3      3  wednesday     4     1   rain
# 4      4   thursday     3     4  sunny
# 5      5     friday     5     6   snow
# 6      6   saturday     7     7  sunny

# %%
df.set_index('event', inplace = True)
df
# Out:
#        index        day  temp  wind
# event
# rain       0     sunday    32     5
# sunny      1      monay     3     4
# snow       2    tuesday     2     3
# rain       3  wednesday     4     1
# sunny      4   thursday     3     4
# snow       5     friday     5     6
# sunny      6   saturday     7     7

# %%
df.loc['sunny']
# Out:
#        index       day  temp  wind
# event
# sunny      1     monay     3     4
# sunny      4  thursday     3     4
# sunny      6  saturday     7     7
